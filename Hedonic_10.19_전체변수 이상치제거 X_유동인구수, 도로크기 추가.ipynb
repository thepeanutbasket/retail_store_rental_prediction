# %%
import pandas as pd
import numpy as np

# %%
seoul = pd.read_csv("C:/data/now_used/최종데이터_전체변수.csv")

# %%
seoul
# Out:
#               건축물대장코드  구시군  읍면동    번    지         입주일  상가유형  지하총층  지상총층  \
# 0         11110-10014  종로구  동숭동    1  114  1982-12-24  근린상가     1     5
# 1     11110-100180009  종로구  동숭동    1   67  2008-07-03  기타상가     4     5
# 2     11110-100184402  종로구  관훈동  186    0  2008-12-29  근린상가     0     3
# 3     11110-100190514  종로구  누하동  245    6  2011-09-28  근린상가     0     4
# 4     11110-100190842  종로구  효제동   19    3  2011-10-14  근린상가     0     5
# ...               ...  ...  ...  ...  ...         ...   ...   ...   ...
# 9292       11740-9659  강동구  고덕동  645    4  1988-09-16  근린상가     1     4
# 9293       11740-9676  강동구  명일동  312   42  1980-06-27  근린상가     1     3
# 9294       11740-9698  강동구  명일동  326   11  1981-10-05  근린상가     1     2
# 9295       11740-9843  강동구  둔촌동  609    3  1993-12-06  근린상가     1     4
# 9296       11740-9917  강동구   길동  413    1  2002-02-06  기타상가     4    10
#
#          연면적m2  ...  주중평균유동인구수  주말평균유동인구수  유동인구비율_남성  유동인구비율_여성  유동인구비율_10대  \
# ...

# %%
seoul.columns
# Out:
# Index(['건축물대장코드', '구시군', '읍면동', '번', '지', '입주일', '상가유형', '지하총층', '지상총층',
#        '연면적m2', '주차대수', '승강기수', '경도', '위도', 'usage_area', 'cont_area', 'RENT',
#        'rent_ua', 'rent_ca', 'floor', '전철역명', '지하철거리m', '승객수점수', '건물별전기사용량',
#        '본번별평균사용량', '횡단보도거리m', '건물연차', '가까운아파트', '가까운아파트총세대수', '가까운아파트평균평당가',
#        '아파트거리', '주변세대수점수', '주변평당가점수', '상권코드명', '평균월매출금액', '평균월매출건수',
#        '평균주중매출금액', '평균주말매출금액', '편의점임대료', '공시지가', '행정동생활인구', '토지면적', '도로접면',
#        '도로추정크기', '총유동인구수', '주중평균유동인구수', '주말평균유동인구수', '유동인구비율_남성', '유동인구비율_여성',
#        '유동인구비율_10대', '유동인구비율_20대', '유동인구비율_30대', '유동인구비율_40대', '유동인구비율_50대',
#        '유동인구비율_60대'],
#       dtype='object')

# %%
seoul_ua = seoul[['rent_ua', '지하총층', '지상총층',
       '연면적m2', '주차대수', '승강기수', 'usage_area', 'cont_area',
       '지하철거리m', '승객수점수', '건물별전기사용량',
       '본번별평균사용량', '횡단보도거리m', '건물연차', '가까운아파트총세대수', '가까운아파트평균평당가',
       '아파트거리', '주변세대수점수', '주변평당가점수', '평균월매출금액', '평균월매출건수',
       '평균주중매출금액', '평균주말매출금액', '편의점임대료', '공시지가', '행정동생활인구', '토지면적', 
       '도로추정크기', '총유동인구수', '주중평균유동인구수', '주말평균유동인구수', '유동인구비율_남성', '유동인구비율_여성',
       '유동인구비율_10대', '유동인구비율_20대', '유동인구비율_30대', '유동인구비율_40대', '유동인구비율_50대',
       '유동인구비율_60대']]
seoul_ua.head()
# Out:
#      rent_ua  지하총층  지상총층    연면적m2  주차대수  승강기수  usage_area  cont_area  \
# 0  48.387097     1     5  1563.66     0     1       15.50      15.50
# 1  13.155340     4     5  8585.08     7     4      103.00     143.92
# 2  11.891892     0     3   172.11     0     1      185.00     200.00
# 3   3.778770     0     4   233.03     2     0       58.22      58.22
# 4   2.037351     0     5   253.80     0     0       58.90      66.20
#
#      지하철거리m       승객수점수  ...  주중평균유동인구수  주말평균유동인구수  유동인구비율_남성  유동인구비율_여성  \
# 0  1.082077   71533.898  ...   107361.4   104675.0      48.45      51.55
# 1  1.373136  117064.164  ...   107361.4   104675.0      48.45      51.55
# 2  2.508637   46623.003  ...   110721.0    85552.5      55.13      44.87
# 3  4.791703   29040.490  ...   107914.4   100200.5      43.75      56.25
# 4  3.818611   34219.916  ...    54434.8    39022.0      60.91      39.09
#
#    유동인구비율_10대  유동인구비율_20대  유동인구비율_30대  유동인구비율_40대  유동인구비율_50대  유동인구비율_60대
# ...

# %%
# 주차가능여부, 승강기여부 변수 추가
lst = []
[lst.append(1) if i > 0 else lst.append(0) for i in seoul_ua['주차대수']]

seoul_ua['주차가능여부'] = lst

lst = []
[lst.append(1) if i > 0 else lst.append(0) for i in seoul_ua['승강기수']]

seoul_ua['승강기여부'] = lst

seoul_ua
# Out:
# <ipython-input-6-f653761b9a8a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_ua['주차가능여부'] = lst
# <ipython-input-6-f653761b9a8a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_ua['승강기여부'] = lst
#         rent_ua  지하총층  지상총층     연면적m2  주차대수  승강기수  usage_area  cont_area  \
# 0     48.387097     1     5   1563.66     0     1       15.50      15.50
# 1     13.155340     4     5   8585.08     7     4      103.00     143.92
# ...

# %%
# 0값 제거
seoul_ua1 = seoul_ua.copy()

seoul_ua1 = seoul_ua1[seoul_ua1.rent_ua != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.지상총층 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.연면적m2 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.usage_area != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.cont_area != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.지하철거리m != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.승객수점수 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.건물별전기사용량 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.본번별평균사용량 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.횡단보도거리m != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.가까운아파트총세대수 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.가까운아파트평균평당가 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.아파트거리 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.주변세대수점수 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.주변평당가점수 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.평균월매출금액 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.평균월매출건수 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.평균주중매출금액 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.평균주말매출금액 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.공시지가 != 0]
seoul_ua1 = seoul_ua1[seoul_ua1.행정동생활인구 != 0]
seoul_ua1
# Out:
#         rent_ua  지하총층  지상총층     연면적m2  주차대수  승강기수  usage_area  cont_area  \
# 0     48.387097     1     5   1563.66     0     1       15.50      15.50
# 1     13.155340     4     5   8585.08     7     4      103.00     143.92
# 2     11.891892     0     3    172.11     0     1      185.00     200.00
# 3      3.778770     0     4    233.03     2     0       58.22      58.22
# 4      2.037351     0     5    253.80     0     0       58.90      66.20
# ...         ...   ...   ...       ...   ...   ...         ...        ...
# 9292   2.156190     1     4    493.71     3     0      783.79     891.83
# 9293  10.439427     1     3    988.04     0     0       41.19      41.19
# 9294   3.761755     1     2    741.99     4     0      127.60     127.60
# 9295   4.672416     1     4    659.00     5     0      291.07     321.87
# 9296   3.905050     4    10  20582.74   149     2      227.91     300.00
#
#         지하철거리m       승객수점수  ...  유동인구비율_남성  유동인구비율_여성  유동인구비율_10대  유동인구비율_20대  \
# ...

# %%
seoul_ua2 = seoul_ua1.copy()
seoul_ua2
# Out:
#         rent_ua  지하총층  지상총층     연면적m2  주차대수  승강기수  usage_area  cont_area  \
# 0     48.387097     1     5   1563.66     0     1       15.50      15.50
# 1     13.155340     4     5   8585.08     7     4      103.00     143.92
# 2     11.891892     0     3    172.11     0     1      185.00     200.00
# 3      3.778770     0     4    233.03     2     0       58.22      58.22
# 4      2.037351     0     5    253.80     0     0       58.90      66.20
# ...         ...   ...   ...       ...   ...   ...         ...        ...
# 9292   2.156190     1     4    493.71     3     0      783.79     891.83
# 9293  10.439427     1     3    988.04     0     0       41.19      41.19
# 9294   3.761755     1     2    741.99     4     0      127.60     127.60
# 9295   4.672416     1     4    659.00     5     0      291.07     321.87
# 9296   3.905050     4    10  20582.74   149     2      227.91     300.00
#
#         지하철거리m       승객수점수  ...  유동인구비율_남성  유동인구비율_여성  유동인구비율_10대  유동인구비율_20대  \
# ...

# %%
seoul_ua2_log = seoul_ua2.copy()

q1 = seoul_ua2_log["rent_ua"].quantile(0.25)
q3 = seoul_ua2_log["rent_ua"].quantile(0.75)
iqt = 6.0 * (q3 - q1)
seoul_ua2_log["rent_ua"][(seoul_ua2_log["rent_ua"] > (q3 + iqt)) | (seoul_ua2_log["rent_ua"] < (q1 - iqt))] = None

seoul_ua2_log = seoul_ua2_log.dropna(axis = 0, how= 'any')

seoul_ua2_log
# Out:
# <ipython-input-9-edd2a03d0792>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_ua2_log["rent_ua"][(seoul_ua2_log["rent_ua"] > (q3 + iqt)) | (seoul_ua2_log["rent_ua"] < (q1 - iqt))] = None
#         rent_ua  지하총층  지상총층     연면적m2  주차대수  승강기수  usage_area  cont_area  \
# 1     13.155340     4     5   8585.08     7     4      103.00     143.92
# 2     11.891892     0     3    172.11     0     1      185.00     200.00
# 3      3.778770     0     4    233.03     2     0       58.22      58.22
# 4      2.037351     0     5    253.80     0     0       58.90      66.20
# 6      4.323740     5     6   3869.33     4     2      370.05     370.05
# ...         ...   ...   ...       ...   ...   ...         ...        ...
# 9292   2.156190     1     4    493.71     3     0      783.79     891.83
# ...

# %%
# 요약 통계량 확인하기

seoul_ua2_log = seoul_ua2_log[seoul_ua2_log['연면적m2'] != 0]
seoul_ua2_log.describe()
# Out:
#            rent_ua         지하총층         지상총층          연면적m2         주차대수  \
# count  9243.000000  9243.000000  9243.000000    9243.000000  9243.000000
# mean      4.686849     1.124851     4.701179    2394.908930    12.221573
# std       2.863804     0.934556     3.376547    8398.181051    61.591305
# min       0.297063     0.000000     1.000000       1.650000     0.000000
# 25%       2.805545     1.000000     3.000000     382.860000     0.000000
# 50%       3.928571     1.000000     4.000000     675.960000     2.000000
# 75%       5.666667     1.000000     5.000000    1262.335000     5.000000
# max      22.881356     8.000000    49.000000  187744.190000  1701.000000
#
#               승강기수    usage_area      cont_area       지하철거리m         승객수점수  \
# count  9243.000000   9243.000000    9243.000000  9243.000000  9.243000e+03
# mean      0.429514    303.831970     443.634607     4.541703  6.351584e+04
# std       1.286776    624.291933    6456.996578     3.041727  6.857637e+04
# ...

# %%
seoul_ua2_log.columns
# Out:
# Index(['rent_ua', '지하총층', '지상총층', '연면적m2', '주차대수', '승강기수', 'usage_area',
#        'cont_area', '지하철거리m', '승객수점수', '건물별전기사용량', '본번별평균사용량', '횡단보도거리m',
#        '건물연차', '가까운아파트총세대수', '가까운아파트평균평당가', '아파트거리', '주변세대수점수', '주변평당가점수',
#        '평균월매출금액', '평균월매출건수', '평균주중매출금액', '평균주말매출금액', '편의점임대료', '공시지가',
#        '행정동생활인구', '토지면적', '도로추정크기', '총유동인구수', '주중평균유동인구수', '주말평균유동인구수',
#        '유동인구비율_남성', '유동인구비율_여성', '유동인구비율_10대', '유동인구비율_20대', '유동인구비율_30대',
#        '유동인구비율_40대', '유동인구비율_50대', '유동인구비율_60대', '주차가능여부', '승강기여부'],
#       dtype='object')

# %%
columns = ['rent_ua', '연면적m2', 'usage_area',
       'cont_area', '지하철거리m', '승객수점수', '건물별전기사용량', '본번별평균사용량', '횡단보도거리m',
       '건물연차', '가까운아파트총세대수', '가까운아파트평균평당가', '아파트거리', '주변세대수점수', '주변평당가점수',
       '평균월매출금액', '평균월매출건수', '평균주중매출금액', '평균주말매출금액', '편의점임대료', '공시지가',
       '행정동생활인구','토지면적','총유동인구수', '주중평균유동인구수', '주말평균유동인구수',
       '유동인구비율_남성', '유동인구비율_여성', '유동인구비율_10대', '유동인구비율_20대', '유동인구비율_30대',
       '유동인구비율_40대', '유동인구비율_50대', '유동인구비율_60대']

# %%
# columns에 담긴 변수 log 취하고 scaling
# 도로추정크기에는 0이 들어있으므로 아래에서 다시 실행한다.

import math
from sklearn import preprocessing

for i in columns:
    seoul_ua2_log['{}_log'.format(i)] = np.log(seoul_ua2_log['{}'.format(i)])
    
seoul_ua2_log
# Out:
# C:\python\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#         rent_ua  지하총층  지상총층     연면적m2  주차대수  승강기수  usage_area  cont_area  \
# 1     13.155340     4     5   8585.08     7     4      103.00     143.92
# 2     11.891892     0     3    172.11     0     1      185.00     200.00
# 3      3.778770     0     4    233.03     2     0       58.22      58.22
# 4      2.037351     0     5    253.80     0     0       58.90      66.20
# 6      4.323740     5     6   3869.33     4     2      370.05     370.05
# ...         ...   ...   ...       ...   ...   ...         ...        ...
# 9292   2.156190     1     4    493.71     3     0      783.79     891.83
# 9293  10.439427     1     3    988.04     0     0       41.19      41.19
# 9294   3.761755     1     2    741.99     4     0      127.60     127.60
# 9295   4.672416     1     4    659.00     5     0      291.07     321.87
# ...

# %%
seoul_ua2_log.columns
# Out:
# Index(['rent_ua', '지하총층', '지상총층', '연면적m2', '주차대수', '승강기수', 'usage_area',
#        'cont_area', '지하철거리m', '승객수점수', '건물별전기사용량', '본번별평균사용량', '횡단보도거리m',
#        '건물연차', '가까운아파트총세대수', '가까운아파트평균평당가', '아파트거리', '주변세대수점수', '주변평당가점수',
#        '평균월매출금액', '평균월매출건수', '평균주중매출금액', '평균주말매출금액', '편의점임대료', '공시지가',
#        '행정동생활인구', '토지면적', '도로추정크기', '총유동인구수', '주중평균유동인구수', '주말평균유동인구수',
#        '유동인구비율_남성', '유동인구비율_여성', '유동인구비율_10대', '유동인구비율_20대', '유동인구비율_30대',
#        '유동인구비율_40대', '유동인구비율_50대', '유동인구비율_60대', '주차가능여부', '승강기여부',
#        'rent_ua_log', '연면적m2_log', 'usage_area_log', 'cont_area_log',
#        '지하철거리m_log', '승객수점수_log', '건물별전기사용량_log', '본번별평균사용량_log',
#        '횡단보도거리m_log', '건물연차_log', '가까운아파트총세대수_log', '가까운아파트평균평당가_log',
#        '아파트거리_log', '주변세대수점수_log', '주변평당가점수_log', '평균월매출금액_log', '평균월매출건수_log',
#        '평균주중매출금액_log', '평균주말매출금액_log', '편의점임대료_log', '공시지가_log', '행정동생활인구_log',
#        '토지면적_log', '총유동인구수_log', '주중평균유동인구수_log', '주말평균유동인구수_log',
# ...

# %%
# 도로추정크기에 0이 있는 경우는 그대로 0, 아닌 경우만 log 씌우기

lst = []
for i in seoul_ua2_log['도로추정크기']:
    if i == 0:
        lst.append(0)
    else:
        lst.append(np.log(i))
        
len(lst)
# Out:
# 9243

# %%
seoul_ua2_log['도로추정크기_log'] = lst

seoul_ua2_log
# Out:
#         rent_ua  지하총층  지상총층     연면적m2  주차대수  승강기수  usage_area  cont_area  \
# 1     13.155340     4     5   8585.08     7     4      103.00     143.92
# 2     11.891892     0     3    172.11     0     1      185.00     200.00
# 3      3.778770     0     4    233.03     2     0       58.22      58.22
# 4      2.037351     0     5    253.80     0     0       58.90      66.20
# 6      4.323740     5     6   3869.33     4     2      370.05     370.05
# ...         ...   ...   ...       ...   ...   ...         ...        ...
# 9292   2.156190     1     4    493.71     3     0      783.79     891.83
# 9293  10.439427     1     3    988.04     0     0       41.19      41.19
# 9294   3.761755     1     2    741.99     4     0      127.60     127.60
# 9295   4.672416     1     4    659.00     5     0      291.07     321.87
# 9296   3.905050     4    10  20582.74   149     2      227.91     300.00
#
#         지하철거리m       승객수점수  ...  주말평균유동인구수_log  유동인구비율_남성_log  유동인구비율_여성_log  \
# ...

# %%
# 반로그함수 / 이상값 제거O(seoul_ua2_log), 설명변수: 연면적m2, usage_area, 공시지가, 평균주말매출금액

# 회귀분석 모듈 import

from statsmodels.formula.api import ols

# 모형 만들기
model = ols('rent_ua_log ~ usage_area + cont_area + 지하총층 + 지상총층 + 연면적m2 + 주차대수 + 승강기수 + 지하철거리m + 승객수점수 + 횡단보도거리m + 건물별전기사용량 + 본번별평균사용량 + 건물연차 + 공시지가 + 가까운아파트총세대수 + 가까운아파트평균평당가 + 아파트거리 + 주변세대수점수 + 주변평당가점수 + 평균월매출금액 + 평균월매출건수 + 평균주중매출금액 + 평균주말매출금액 + 편의점임대료 + 주차가능여부 + 승강기여부 + 행정동생활인구 + 토지면적 + 도로추정크기 + 총유동인구수 + 주중평균유동인구수 + 주말평균유동인구수 + 유동인구비율_남성 + 유동인구비율_여성 + 유동인구비율_10대 + 유동인구비율_20대 + 유동인구비율_30대 + 유동인구비율_40대 + 유동인구비율_50대 + 유동인구비율_60대 + 주차가능여부 + 승강기여부', seoul_ua2_log)

# 모형 적합
res = model.fit()

# 분석 결과 확인
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            rent_ua_log   R-squared:                       0.377
# Model:                            OLS   Adj. R-squared:                  0.375
# Method:                 Least Squares   F-statistic:                     139.5
# Date:                Mon, 19 Oct 2020   Prob (F-statistic):               0.00
# Time:                        14:05:08   Log-Likelihood:                -5154.3
# No. Observations:                9243   AIC:                         1.039e+04
# Df Residuals:                    9202   BIC:                         1.068e+04
# Df Model:                          40
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    -626.4057    244.110     -2.566      0.010   -1104.916    -147.896
# ...

# %%
# 다중공선성 확인을 위한 모듈

from statsmodels.stats.outliers_influence import variance_inflation_factor

# 한번에 모든 컬럼의 VIF를 계산

pd.DataFrame({'컬럼': column, 'VIF': variance_inflation_factor(model.exog, i)} 
             for i, column in enumerate(model.exog_names)
             if column != 'Intercept')  # 절편의 VIF는 구하지 않는다.
# Out:
#              컬럼           VIF
# 0    usage_area  1.107776e+00
# 1     cont_area  1.014701e+00
# 2          지하총층  2.426983e+00
# 3          지상총층  4.882170e+00
# 4         연면적m2  2.977563e+01
# 5          주차대수  1.040183e+01
# 6          승강기수  8.610281e+00
# 7        지하철거리m  1.294795e+00
# 8         승객수점수  1.460732e+00
# 9       횡단보도거리m  1.267535e+00
# 10     건물별전기사용량  5.539848e+00
# 11     본번별평균사용량  2.456833e+00
# 12         건물연차  2.020608e+00
# 13         공시지가  2.362681e+00
# 14   가까운아파트총세대수  2.269412e+00
# 15  가까운아파트평균평당가  1.865768e+00
# 16        아파트거리  1.291319e+00
# 17      주변세대수점수  2.562343e+00
# 18      주변평당가점수  2.237975e+00
# 19      평균월매출금액  1.592586e+00
# 20      평균월매출건수  4.088381e+00
# 21     평균주중매출금액  1.276173e+00
# 22     평균주말매출금액  4.775549e+00
# 23       편의점임대료  1.261958e+00
# 24       주차가능여부  1.481189e+00
# 25        승강기여부  2.885407e+00
# 26      행정동생활인구  1.337504e+00
# 27         토지면적  2.329372e+00
# 28       도로추정크기  1.585044e+00
# 29       총유동인구수  8.052265e+09
# ...

# %%
# 모형 만들기
model = ols('rent_ua_log ~ 연면적m2 + 공시지가 + 평균주말매출금액 + usage_area + 승객수점수 + 건물별전기사용량 + 도로추정크기 + 유동인구비율_10대 + 유동인구비율_20대 + 유동인구비율_30대 + 유동인구비율_40대 + 유동인구비율_50대 + 유동인구비율_60대', seoul_ua2_log)

# 모형 적합
res = model.fit()

# 분석 결과 확인
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            rent_ua_log   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.350
# Method:                 Least Squares   F-statistic:                     384.2
# Date:                Mon, 19 Oct 2020   Prob (F-statistic):               0.00
# Time:                        14:05:09   Log-Likelihood:                -5345.7
# No. Observations:                9243   AIC:                         1.072e+04
# Df Residuals:                    9229   BIC:                         1.082e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -219.0231     59.664     -3.671      0.000    -335.978    -102.069
# ...

# %%
# 한번에 모든 컬럼의 VIF를 계산

pd.DataFrame({'컬럼': column, 'VIF': variance_inflation_factor(model.exog, i)} 
             for i, column in enumerate(model.exog_names)
             if column != 'Intercept')  # 절편의 VIF는 구하지 않는다.
# Out:
#             컬럼           VIF
# 0        연면적m2  4.037469e+00
# 1         공시지가  1.814064e+00
# 2     평균주말매출금액  1.442607e+00
# 3   usage_area  1.053865e+00
# 4        승객수점수  1.246069e+00
# 5     건물별전기사용량  4.095712e+00
# 6       도로추정크기  1.291935e+00
# 7   유동인구비율_10대  2.934401e+05
# 8   유동인구비율_20대  1.653593e+06
# 9   유동인구비율_30대  4.030674e+05
# 10  유동인구비율_40대  1.816501e+05
# 11  유동인구비율_50대  3.489765e+05
# 12  유동인구비율_60대  3.448217e+05

# %%
seoul_ua2_log.columns
# Out:
# Index(['rent_ua', '지하총층', '지상총층', '연면적m2', '주차대수', '승강기수', 'usage_area',
#        'cont_area', '지하철거리m', '승객수점수', '건물별전기사용량', '본번별평균사용량', '횡단보도거리m',
#        '건물연차', '가까운아파트총세대수', '가까운아파트평균평당가', '아파트거리', '주변세대수점수', '주변평당가점수',
#        '평균월매출금액', '평균월매출건수', '평균주중매출금액', '평균주말매출금액', '편의점임대료', '공시지가',
#        '행정동생활인구', '토지면적', '도로추정크기', '총유동인구수', '주중평균유동인구수', '주말평균유동인구수',
#        '유동인구비율_남성', '유동인구비율_여성', '유동인구비율_10대', '유동인구비율_20대', '유동인구비율_30대',
#        '유동인구비율_40대', '유동인구비율_50대', '유동인구비율_60대', '주차가능여부', '승강기여부',
#        'rent_ua_log', '연면적m2_log', 'usage_area_log', 'cont_area_log',
#        '지하철거리m_log', '승객수점수_log', '건물별전기사용량_log', '본번별평균사용량_log',
#        '횡단보도거리m_log', '건물연차_log', '가까운아파트총세대수_log', '가까운아파트평균평당가_log',
#        '아파트거리_log', '주변세대수점수_log', '주변평당가점수_log', '평균월매출금액_log', '평균월매출건수_log',
#        '평균주중매출금액_log', '평균주말매출금액_log', '편의점임대료_log', '공시지가_log', '행정동생활인구_log',
#        '토지면적_log', '총유동인구수_log', '주중평균유동인구수_log', '주말평균유동인구수_log',
# ...

# %%
seoul_ua2_log[['rent_ua', '지하총층', '지상총층', '연면적m2', '주차대수', '승강기수', 'usage_area',
       'cont_area', '지하철거리m', '승객수점수', '건물별전기사용량', '본번별평균사용량', '횡단보도거리m',
       '건물연차', '가까운아파트총세대수', '가까운아파트평균평당가', '아파트거리', '주변세대수점수', '주변평당가점수',
       '평균월매출금액', '평균월매출건수', '평균주중매출금액', '평균주말매출금액', '편의점임대료', '공시지가',
       '행정동생활인구', '토지면적', '도로추정크기', '총유동인구수', '주중평균유동인구수', '주말평균유동인구수',
       '유동인구비율_남성', '유동인구비율_여성', '유동인구비율_10대', '유동인구비율_20대', '유동인구비율_30대',
       '유동인구비율_40대', '유동인구비율_50대', '유동인구비율_60대', '주차가능여부', '승강기여부',]].isnull().sum()
# Out:
# rent_ua        0
# 지하총층           0
# 지상총층           0
# 연면적m2          0
# 주차대수           0
# 승강기수           0
# usage_area     0
# cont_area      0
# 지하철거리m         0
# 승객수점수          0
# 건물별전기사용량       0
# 본번별평균사용량       0
# 횡단보도거리m        0
# 건물연차           0
# 가까운아파트총세대수     0
# 가까운아파트평균평당가    0
# 아파트거리          0
# 주변세대수점수        0
# 주변평당가점수        0
# 평균월매출금액        0
# 평균월매출건수        0
# 평균주중매출금액       0
# 평균주말매출금액       0
# 편의점임대료         0
# 공시지가           0
# 행정동생활인구        0
# 토지면적           0
# 도로추정크기         0
# 총유동인구수         0
# 주중평균유동인구수      0
# 주말평균유동인구수      0
# 유동인구비율_남성      0
# 유동인구비율_여성      0
# 유동인구비율_10대     0
# 유동인구비율_20대     0
# 유동인구비율_30대     0
# 유동인구비율_40대     0
# 유동인구비율_50대     0
# 유동인구비율_60대     0
# 주차가능여부         0
# 승강기여부          0
# dtype: int64

# %%
seoul_ua2_log[['rent_ua_log', '연면적m2_log', 'usage_area_log', 'cont_area_log',
       '지하철거리m_log', '승객수점수_log', '건물별전기사용량_log', '본번별평균사용량_log',
       '횡단보도거리m_log', '건물연차_log', '가까운아파트총세대수_log', '가까운아파트평균평당가_log',
       '아파트거리_log', '주변세대수점수_log', '주변평당가점수_log', '평균월매출금액_log', '평균월매출건수_log',
       '평균주중매출금액_log', '평균주말매출금액_log', '편의점임대료_log', '공시지가_log', '행정동생활인구_log',
       '토지면적_log', '도로추정크기_log', '총유동인구수_log', '주중평균유동인구수_log',
       '주말평균유동인구수_log', '유동인구비율_남성_log', '유동인구비율_여성_log', '유동인구비율_10대_log',
       '유동인구비율_20대_log', '유동인구비율_30대_log', '유동인구비율_40대_log', '유동인구비율_50대_log',
       '유동인구비율_60대_log']].isnull().sum()
# Out:
# rent_ua_log           0
# 연면적m2_log             0
# usage_area_log        0
# cont_area_log         0
# 지하철거리m_log            0
# 승객수점수_log             0
# 건물별전기사용량_log          0
# 본번별평균사용량_log          0
# 횡단보도거리m_log           0
# 건물연차_log              0
# 가까운아파트총세대수_log        0
# 가까운아파트평균평당가_log       0
# 아파트거리_log             0
# 주변세대수점수_log           0
# 주변평당가점수_log           0
# 평균월매출금액_log        1242
# 평균월매출건수_log           0
# 평균주중매출금액_log        318
# 평균주말매출금액_log          0
# 편의점임대료_log            0
# 공시지가_log              0
# 행정동생활인구_log           0
# 토지면적_log              0
# 도로추정크기_log            0
# 총유동인구수_log            0
# 주중평균유동인구수_log         0
# 주말평균유동인구수_log         0
# 유동인구비율_남성_log         0
# 유동인구비율_여성_log         0
# 유동인구비율_10대_log        0
# 유동인구비율_20대_log        0
# 유동인구비율_30대_log        0
# 유동인구비율_40대_log        0
# 유동인구비율_50대_log        0
# 유동인구비율_60대_log        0
# dtype: int64

# %%
# 평균월매출금액_log, 평균주중매출금액_log에 결측치가 많아서 그냥 변수에서 제거

seoul_ua3_log = seoul_ua2_log[['rent_ua', '지하총층', '지상총층', '연면적m2', '주차대수', '승강기수', 'usage_area',
       'cont_area', '지하철거리m', '승객수점수', '건물별전기사용량', '본번별평균사용량', '횡단보도거리m',
       '건물연차', '가까운아파트총세대수', '가까운아파트평균평당가', '아파트거리', '주변세대수점수', '주변평당가점수',
       '평균월매출금액', '평균월매출건수', '평균주중매출금액', '평균주말매출금액', '편의점임대료', '공시지가',
       '행정동생활인구', '토지면적', '도로추정크기', '총유동인구수', '주중평균유동인구수', '주말평균유동인구수',
       '유동인구비율_남성', '유동인구비율_여성', '유동인구비율_10대', '유동인구비율_20대', '유동인구비율_30대',
       '유동인구비율_40대', '유동인구비율_50대', '유동인구비율_60대', '주차가능여부', '승강기여부',
       'rent_ua_log', '연면적m2_log', 'usage_area_log', 'cont_area_log',
       '지하철거리m_log', '승객수점수_log', '건물별전기사용량_log', '본번별평균사용량_log',
       '횡단보도거리m_log', '건물연차_log', '가까운아파트총세대수_log', '가까운아파트평균평당가_log',
       '아파트거리_log', '주변세대수점수_log', '주변평당가점수_log', '평균월매출건수_log',
       '평균주말매출금액_log', '편의점임대료_log', '공시지가_log', '행정동생활인구_log',
       '토지면적_log', '도로추정크기_log', '총유동인구수_log', '주중평균유동인구수_log',
       '주말평균유동인구수_log', '유동인구비율_남성_log', '유동인구비율_여성_log', '유동인구비율_10대_log',
       '유동인구비율_20대_log', '유동인구비율_30대_log', '유동인구비율_40대_log', '유동인구비율_50대_log',
       '유동인구비율_60대_log']]

seoul_ua3_log
# Out:
#         rent_ua  지하총층  지상총층     연면적m2  주차대수  승강기수  usage_area  cont_area  \
# 1     13.155340     4     5   8585.08     7     4      103.00     143.92
# 2     11.891892     0     3    172.11     0     1      185.00     200.00
# 3      3.778770     0     4    233.03     2     0       58.22      58.22
# 4      2.037351     0     5    253.80     0     0       58.90      66.20
# 6      4.323740     5     6   3869.33     4     2      370.05     370.05
# ...         ...   ...   ...       ...   ...   ...         ...        ...
# 9292   2.156190     1     4    493.71     3     0      783.79     891.83
# 9293  10.439427     1     3    988.04     0     0       41.19      41.19
# 9294   3.761755     1     2    741.99     4     0      127.60     127.60
# 9295   4.672416     1     4    659.00     5     0      291.07     321.87
# 9296   3.905050     4    10  20582.74   149     2      227.91     300.00
#
#         지하철거리m       승객수점수  ...  주중평균유동인구수_log  주말평균유동인구수_log  유동인구비율_남성_log  \
# ...

# %%
# 상관계수 확인

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.rcParams['font.family'] = 'NanumGothic'

# 스피어만 상관계수

corr_ua_s = seoul_ua2.corr(method = 'spearman')
corr_ua_s
# Out:
#               rent_ua      지하총층      지상총층     연면적m2      주차대수      승강기수  \
# rent_ua      1.000000  0.139950  0.165470  0.199069  0.073876  0.200180
# 지하총층         0.139950  1.000000  0.501055  0.599768  0.333720  0.409197
# 지상총층         0.165470  0.501055  1.000000  0.735451  0.559241  0.633854
# 연면적m2        0.199069  0.599768  0.735451  1.000000  0.570521  0.568021
# 주차대수         0.073876  0.333720  0.559241  0.570521  1.000000  0.465206
# 승강기수         0.200180  0.409197  0.633854  0.568021  0.465206  1.000000
# usage_area   0.022925  0.179285  0.248413  0.299714  0.207975  0.234520
# cont_area    0.066757  0.222174  0.285932  0.348036  0.238002  0.270518
# 지하철거리m      -0.260766 -0.018173 -0.022139 -0.008622  0.050741 -0.050312
# 승객수점수        0.377356  0.171560  0.183132  0.164859  0.062975  0.188492
# 건물별전기사용량     0.341907  0.442518  0.461049  0.732131  0.358169  0.422305
# 본번별평균사용량     0.390825  0.376268  0.358138  0.543686  0.280323  0.350493
# ...

# %%
import matplotlib.pylab as plt
from matplotlib import pyplot
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname = 'C:/windows/fonts/malgun.ttf').get_name()
rc('font', family = font_name)

# %%
# 스피어만 상관계수 히트맵

mask = np.zeros_like(corr_ua_s, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots( figsize=(20,20) )

sns.heatmap(corr_ua_s,
            cmap = 'RdYlBu_r', 
            annot = True,   # 실제 값을 표시한다
            mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,  # 경계면 실선으로 구분하기
            cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
           )  
plt.show()
# Out:
# C:\python\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\python\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 회귀분석 모듈 import

from statsmodels.formula.api import ols

# 모형 만들기(with 모든변수)
model = ols('rent_ua_log ~ 연면적m2_log + usage_area_log+ 지하철거리m_log + 승객수점수_log + 건물별전기사용량_log + 본번별평균사용량_log + 횡단보도거리m_log + 건물연차_log + 가까운아파트총세대수_log + 가까운아파트평균평당가_log + 아파트거리_log + 주변세대수점수_log + 주변평당가점수_log + 평균월매출건수_log + 평균주말매출금액_log + 편의점임대료_log + 공시지가_log + 행정동생활인구_log + 토지면적_log + 도로추정크기_log + 총유동인구수_log + 주중평균유동인구수_log + 주말평균유동인구수_log + 유동인구비율_남성_log + 유동인구비율_여성_log + 유동인구비율_10대_log + 유동인구비율_20대_log + 유동인구비율_30대_log + 유동인구비율_40대_log + 유동인구비율_50대_log + 유동인구비율_60대_log ', seoul_ua3_log)
# 모형 적합
res = model.fit()

# 분석 결과 확인
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            rent_ua_log   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.447
# Method:                 Least Squares   F-statistic:                     242.2
# Date:                Mon, 19 Oct 2020   Prob (F-statistic):               0.00
# Time:                        14:05:12   Log-Likelihood:                -4589.9
# No. Observations:                9243   AIC:                             9244.
# Df Residuals:                    9211   BIC:                             9472.
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# 한번에 모든 컬럼의 VIF를 계산

pd.DataFrame({'컬럼': column, 'VIF': variance_inflation_factor(model.exog, i)} 
             for i, column in enumerate(model.exog_names)
             if column != 'Intercept')  # 절편의 VIF는 구하지 않는다.
# Out:
#                  컬럼          VIF
# 0         연면적m2_log     5.366962
# 1    usage_area_log     1.231983
# 2        지하철거리m_log     1.518461
# 3         승객수점수_log     2.039817
# 4      건물별전기사용량_log     2.924525
# 5      본번별평균사용량_log     2.209297
# 6       횡단보도거리m_log     1.283149
# 7          건물연차_log     1.293061
# 8    가까운아파트총세대수_log     2.400781
# 9   가까운아파트평균평당가_log     2.890172
# 10        아파트거리_log     2.610204
# 11      주변세대수점수_log     2.821249
# 12      주변평당가점수_log     5.382205
# 13      평균월매출건수_log     6.404733
# 14     평균주말매출금액_log     6.071336
# 15       편의점임대료_log     1.389530
# 16         공시지가_log     2.814743
# 17      행정동생활인구_log     1.348123
# 18         토지면적_log     3.780851
# 19       도로추정크기_log     1.738884
# 20       총유동인구수_log  8837.216963
# 21    주중평균유동인구수_log  4773.237384
# 22    주말평균유동인구수_log   708.911487
# 23    유동인구비율_남성_log     9.514429
# 24    유동인구비율_여성_log     9.537513
# 25   유동인구비율_10대_log     2.695206
# 26   유동인구비율_20대_log     8.756549
# ...

# %%
# 모형 만들기(p_value > 0.05, 다중공선성 10 이상 제외)
model = ols('rent_ua_log ~ 연면적m2_log + usage_area_log+ 지하철거리m_log + 승객수점수_log + 건물별전기사용량_log + 본번별평균사용량_log + 횡단보도거리m_log + 건물연차_log + 평균월매출건수_log + 평균주말매출금액_log + 편의점임대료_log + 공시지가_log + 도로추정크기_log + 유동인구비율_20대_log + 유동인구비율_30대_log', seoul_ua3_log)
# 모형 적합
res = model.fit()

# 분석 결과 확인
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            rent_ua_log   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.444
# Method:                 Least Squares   F-statistic:                     493.1
# Date:                Mon, 19 Oct 2020   Prob (F-statistic):               0.00
# Time:                        14:05:13   Log-Likelihood:                -4624.0
# No. Observations:                9243   AIC:                             9280.
# Df Residuals:                    9227   BIC:                             9394.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# 한번에 모든 컬럼의 VIF를 계산

pd.DataFrame({'컬럼': column, 'VIF': variance_inflation_factor(model.exog, i)} 
             for i, column in enumerate(model.exog_names)
             if column != 'Intercept')  # 절편의 VIF는 구하지 않는다.
# Out:
#                 컬럼       VIF
# 0        연면적m2_log  3.154014
# 1   usage_area_log  1.207915
# 2       지하철거리m_log  1.436439
# 3        승객수점수_log  1.972620
# 4     건물별전기사용량_log  2.887716
# 5     본번별평균사용량_log  2.120858
# 6      횡단보도거리m_log  1.263292
# 7         건물연차_log  1.251884
# 8      평균월매출건수_log  4.713634
# 9     평균주말매출금액_log  4.407672
# 10      편의점임대료_log  1.341095
# 11        공시지가_log  2.081619
# 12      도로추정크기_log  1.604598
# 13  유동인구비율_20대_log  1.486254
# 14  유동인구비율_30대_log  1.332213

# %%
# 모형 만들기(usage_area, 공시지가, 매출, 유동인구수, 도로추정크기)
model = ols('rent_ua_log ~ 연면적m2_log + 공시지가_log + 승객수점수_log + 건물별전기사용량_log + 건물연차_log + 평균주말매출금액_log + usage_area_log + 도로추정크기_log + 유동인구비율_20대_log + 유동인구비율_30대_log', seoul_ua2_log)

# 모형 적합
res = model.fit()

# 분석 결과 확인
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            rent_ua_log   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.427
# Method:                 Least Squares   F-statistic:                     688.8
# Date:                Mon, 19 Oct 2020   Prob (F-statistic):               0.00
# Time:                        14:05:13   Log-Likelihood:                -4768.7
# No. Observations:                9243   AIC:                             9559.
# Df Residuals:                    9232   BIC:                             9638.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# 한번에 모든 컬럼의 VIF를 계산

pd.DataFrame({'컬럼': column, 'VIF': variance_inflation_factor(model.exog, i)} 
             for i, column in enumerate(model.exog_names)
             if column != 'Intercept')  # 절편의 VIF는 구하지 않는다.
# Out:
#                컬럼       VIF
# 0       연면적m2_log  2.929623
# 1        공시지가_log  1.840595
# 2       승객수점수_log  1.474118
# 3    건물별전기사용량_log  2.535264
# 4        건물연차_log  1.245491
# 5    평균주말매출금액_log  1.487175
# 6  usage_area_log  1.191148
# 7      도로추정크기_log  1.339537
# 8  유동인구비율_20대_log  1.349812
# 9  유동인구비율_30대_log  1.308591

# %%
seoul_ua2_log.columns
# Out:
# Index(['rent_ua', '지하총층', '지상총층', '연면적m2', '주차대수', '승강기수', 'usage_area',
#        'cont_area', '지하철거리m', '승객수점수', '건물별전기사용량', '본번별평균사용량', '횡단보도거리m',
#        '건물연차', '가까운아파트총세대수', '가까운아파트평균평당가', '아파트거리', '주변세대수점수', '주변평당가점수',
#        '평균월매출금액', '평균월매출건수', '평균주중매출금액', '평균주말매출금액', '편의점임대료', '공시지가',
#        '행정동생활인구', '토지면적', '도로추정크기', '총유동인구수', '주중평균유동인구수', '주말평균유동인구수',
#        '유동인구비율_남성', '유동인구비율_여성', '유동인구비율_10대', '유동인구비율_20대', '유동인구비율_30대',
#        '유동인구비율_40대', '유동인구비율_50대', '유동인구비율_60대', '주차가능여부', '승강기여부',
#        'rent_ua_log', '연면적m2_log', 'usage_area_log', 'cont_area_log',
#        '지하철거리m_log', '승객수점수_log', '건물별전기사용량_log', '본번별평균사용량_log',
#        '횡단보도거리m_log', '건물연차_log', '가까운아파트총세대수_log', '가까운아파트평균평당가_log',
#        '아파트거리_log', '주변세대수점수_log', '주변평당가점수_log', '평균월매출금액_log', '평균월매출건수_log',
#        '평균주중매출금액_log', '평균주말매출금액_log', '편의점임대료_log', '공시지가_log', '행정동생활인구_log',
#        '토지면적_log', '총유동인구수_log', '주중평균유동인구수_log', '주말평균유동인구수_log',
# ...

# %%
seoul_ua2_log[['rent_ua_log', '연면적m2_log', 'usage_area_log', '지하철거리m_log', '승객수점수_log', '건물별전기사용량_log', '본번별평균사용량_log', '횡단보도거리m_log', '건물연차_log', '평균월매출건수_log', '평균주말매출금액_log', '편의점임대료_log', '공시지가_log', '도로추정크기_log','유동인구비율_20대_log',
       '유동인구비율_30대_log']].to_csv("C:/data/now_used/1019_data2_afewvalues.csv", index = False)
